# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install albumentations timm -q

# %%
import shutil, os

# Copy model files
# !cp "/content/drive/MyDrive/GBCD/model.py" "/content/"
# !cp "/content/drive/MyDrive/GBCD/train_hybridsiam_plus.py" "/content/"
# !cp "/content/drive/MyDrive/GBCD/model.pth" "/content/"

# Copy dataset
# !cp -r "/content/drive/MyDrive/GBCD/GBCD-Binary" "/content/GBCD-Binary"

print("Files copied!")
# Out:
# ^C
# Files copied!

# %%
# Read the script
with open('/content/train_hybridsiam_plus.py') as f:
    src = f.read()

# Update paths to Colab paths
src = src.replace(
    r'C:\Users\Mohammed\My research\GBCD\model.pth',
    '/content/model.pth'
)
src = src.replace(
    r'C:\Users\Mohammed\My research\GBCD\GBCD-Binary',
    '/content/GBCD-Binary'
)
src = src.replace(
    r'C:\Users\Mohammed\My research\GBCD\runs\hybridsiam_plus',
    '/content/runs/hybridsiam_plus'
)
src = src.replace(
    'NUM_WORKERS   = 0',
    'NUM_WORKERS   = 2'
)
src = src.replace(
    'BATCH_SIZE    = 2',
    'BATCH_SIZE    = 8'
)

# Save updated script
with open('/content/train_hybridsiam_plus.py', 'w') as f:
    f.write(src)

print("Paths updated!")
print("BATCH_SIZE set to 8 (T4 has 15GB VRAM)")
# Out:
# Paths updated!
# BATCH_SIZE set to 8 (T4 has 15GB VRAM)

# %%
# !nvidia-smi
# Out:
# Sun May 24 21:10:16 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   40C    P8             10W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# %cd /content
# !python train_hybridsiam_plus.py
# Out:
# /content
# ...
#   HybridSiam-CD+  |  CBAM + Temporal Fusion + Focal Loss
# ...
# Device        : cuda
# Data root     : /content/GBCD-Binary
# Pretrained    : /content/model.pth
# Save dir      : /content/runs/hybridsiam_plus
# IMG_SIZE      : 512   BATCH_SIZE : 8
# Epochs        : 50  patience=10
# Freeze ViT    : True
# Warmup epochs : 5
# -----------------------------------------------------------------
# Train : 637 samples (non-empty only)
# Val   : 176 samples
#
# Building HybridSiam-CD+ ...
# [Weight loading]  687/687 keys loaded.
# [VRAM] ViT backbone frozen.
# Parameters : 329,434,637 total | 26,355,213 trainable | 303,079,424 frozen
# [Optimizer]
#   Decoder/ResNet params : 26,211,363  LR=1e-05
#   CBAM params           : 12,010  LR=0.0001
#   Fusion params         : 131,840  LR=0.0001
#
# ...
# Training HybridSiam-CD+ on 512x512 Berlin data
# ...
#
# Epoch 001/50  Train loss=1.5840 IoU=0.1576 F1=0.2723  |  Val loss=1.1017 IoU=0.2377 F1=0.3841 P=0.4281 R=0.3484  LR=4.00e-06  [478s]
# ...

# %%
# !cp /content/runs/hybridsiam_plus/best_model.pth \
    "/content/drive/MyDrive/GBCD/best_model_hybridsiam_plus.pth"
print("Best model saved to Google Drive!")
# Out:
# Best model saved to Google Drive!
